# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !nvidia-smi
# Out:
# Wed May  4 16:13:06 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
# setting path
sys.path.append("/content/drive/MyDrive/simclr")
sys.path.append("/content/drive/MyDrive/simclr/layers")
sys.path.append("/content/drive/MyDrive/simclr/models")
sys.path.append("/content/drive/MyDrive/simclr/loss")
sys.path.append("/content/drive/MyDrive/simclr/optim")
sys.path.append("/content/drive/MyDrive/simclr/dataloader")

# %%
from simclr import SimClr
from ntxent import nt_xent_loss
from ntxentgit import SimCLR_Loss
from augment import TransformsSimCLR
from utils import *
from LARS import LARS
from downstream import DownStream
from dataloader import *
import pickle

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np

# %%
train_loader_simclr = train_loader_simclr("CIFAR10",128)
test_loader = test_loader("CIFAR10",128)
test_images, test_labels = get_testimgs_list("CIFAR10")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
model = SimClr('resnet50').cuda()
temperature = 0.5
#criterion = nt_xent_loss
criterion = SimCLR_Loss(128,0.5)
optimizer = "LARS"
model, train_loss = train_simclr(train_loader_simclr,model,criterion,optimizer,100,128,True,"/content/model1")
# Out:
# /content/drive/MyDrive/simclr/optim/LARS.py:136: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1055.)
#   next_v.mul_(momentum).add_(scaled_lr, grad)
# Epoch: 0, step: 50/390, loss: 5.53007698059082
# Epoch: 0, step: 100/390, loss: 5.467336654663086
# Epoch: 0, step: 150/390, loss: 5.488121032714844
# Epoch: 0, step: 200/390, loss: 5.3604326248168945
# Epoch: 0, step: 250/390, loss: 5.325634002685547
# Epoch: 0, step: 300/390, loss: 5.233689785003662
# Epoch: 0, step: 350/390, loss: 5.174006938934326
# Epoch: 0 completed, average loss: 5.380153981233255, time taken: 3.1905666987101235 mins
# Epoch: 1, step: 50/390, loss: 5.189033031463623
# Epoch: 1, step: 100/390, loss: 5.02957010269165
# Epoch: 1, step: 150/390, loss: 5.08118200302124
# ...

# %%
plt.xlabel("Number of Epochs")
plt.ylabel("NT-XENT")
plt.title("CIFAR10-RES50-BS128-LARS")
plt.plot(train_loss)
plt.savefig("/content/CIFAR10-RES50-BS128-LARS.png")

# %%
with open("/content/CIFAR10-RES50-BS128-LARS", "wb") as fp:   #Pickling
  pickle.dump(train_loss, fp)

# %%
kaan = SimClr('resnet50').cuda()
kaan.load_state_dict(torch.load("/content/model"))
# Out:
# <All keys matched successfully>

# %%
print("kaan")
# Out:
# kaan

# %%
ds = DownStream(kaan.encoder,2048,10).cuda()
optimizer = torch.optim.Adam(ds.parameters(), lr=3e-4)
criterion = torch.nn.CrossEntropyLoss()
train_loader_ds = train_loader_dstream("CIFAR10",128)
model_ds,train_loss_list,train_accuracy_epoch = train_ds(train_loader_ds, None, ds, criterion, optimizer,5,False,path=None)
# Out:
# Files already downloaded and verified
# Epoch: 0, step: 50/390, training_loss: 1.4330676794052124, training_acc: 0.4921875
# Epoch: 0, step: 100/390, training_loss: 1.3109798431396484, training_acc: 0.53125
# Epoch: 0, step: 150/390, training_loss: 1.1956113576889038, training_acc: 0.59375
# Epoch: 0, step: 200/390, training_loss: 1.3983707427978516, training_acc: 0.4609375
# Epoch: 0, step: 250/390, training_loss: 1.2106103897094727, training_acc: 0.5703125
# Epoch: 0, step: 300/390, training_loss: 1.489349126815796, training_acc: 0.5
# Epoch: 0, step: 350/390, training_loss: 1.3359218835830688, training_acc: 0.5
# Epoch: 0 completed, average train loss: 1.3202044554245778, average training_acc: 0.5227363782051282 time taken: 0.42386043469111123 mins
# Epoch: 1, step: 50/390, training_loss: 1.3437806367874146, training_acc: 0.5390625
# Epoch: 1, step: 100/390, training_loss: 1.2469055652618408, training_acc: 0.5390625
# ...

# %%
plot_features(kaan.encoder,test_loader,test_images,test_labels,10,2048,128)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
